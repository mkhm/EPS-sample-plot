# %%
# %matplotlib inline
import numpy as np
import pylab as plt
from numpy import pi

# %%
def f(k, c, t, sign):
    return 0.5*(c+sign*np.sqrt(c**2+16*t**2*np.cos(k*a)**2))

# %%
a = 1
t = 1
c = 1 # c = E(atom A) - deltaV0

k = np.linspace(-pi/(2*a), pi/(2*a))
E1 = f(k, c, t, 1)
E2 = f(k, c, t, -1)

plt.figure(figsize=(10,8))
plt.plot(k, E1, linewidth=3)
plt.plot(k, E2, linewidth=3)
plt.xticks([0, pi/2, -pi/2], ['$0$', '$\pi/2$', '$-\pi/2$'], fontsize=20)
plt.yticks(fontsize=15)
plt.xlabel('$k$', fontsize=20)
plt.ylabel('$E(k)$', fontsize=20)
plt.xlim([pi/2, -pi/2])
plt.title(r'$(1/2)\{C\pm \sqrt{C^2+16^{ } t^2 \cos^2{(ka)}}\}$', fontsize=22)
